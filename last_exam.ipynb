# %%
import pandas as pd
import matplotlib.pyplot as mat
from sklearn import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv('car_evaluation.csv')

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
df.shape
# Out:
# (1727, 7)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]>

# %%
# label_encoders = {}
for column in df.columns:
    # le = LabelEncoder()
    df[column] = LabelEncoder().fit_transform(df[column])
    # label_encoders[column] = le

# %%
df
# Out:
#       vhigh  vhigh.1  2  2.1  small  low  unacc
# 0         3        3  0    0      2    2      2
# 1         3        3  0    0      2    0      2
# 2         3        3  0    0      1    1      2
# 3         3        3  0    0      1    2      2
# 4         3        3  0    0      1    0      2
# ...     ...      ... ..  ...    ...  ...    ...
# 1722      1        1  3    2      1    2      1
# 1723      1        1  3    2      1    0      3
# 1724      1        1  3    2      0    1      2
# 1725      1        1  3    2      0    2      1
# 1726      1        1  3    2      0    0      3
#
# [1727 rows x 7 columns]

# %%
# label_encoders

# %%
df.dtypes
# Out:
# vhigh      int32
# vhigh.1    int32
# 2          int32
# 2.1        int32
# small      int32
# low        int32
# unacc      int32
# dtype: object

# %%
import numpy as np

for i in df.columns:
    if df[i].dtype == np.int32 or df[i].dtype == np.float64:
        mat.figure()
        mat.boxplot(df[i])
        mat.xlabel(i)
        mat.ylabel('range')
        mat.title(f'Boxplot of {i}')
        mat.show()

# %%
df.corr()
# Out:
#                 vhigh       vhigh.1             2           2.1         small  \
# vhigh    1.000000e+00 -1.043357e-03  1.043357e-03  9.523677e-04 -9.523677e-04
# vhigh.1 -1.043357e-03  1.000000e+00  1.043357e-03  9.523677e-04 -9.523677e-04
# 2        1.043357e-03  1.043357e-03  1.000000e+00 -9.523677e-04  9.523677e-04
# 2.1      9.523677e-04  9.523677e-04 -9.523677e-04  1.000000e+00  8.693132e-04
# small   -9.523677e-04 -9.523677e-04  9.523677e-04  8.693132e-04  1.000000e+00
# low     -3.200145e-16 -1.012963e-16  6.731959e-17  2.362177e-17 -7.231156e-18
# unacc    5.105835e-02  3.982107e-02 -3.094953e-02 -2.992590e-01  3.283926e-02
#
#                   low     unacc
# vhigh   -3.200145e-16  0.051058
# vhigh.1 -1.012963e-16  0.039821
# 2        6.731959e-17 -0.030950
# 2.1      2.362177e-17 -0.299259
# small   -7.231156e-18  0.032839
# low      1.000000e+00 -0.021045
# unacc   -2.104530e-02  1.000000

# %%
mat.figure(figsize=(10, 8))
mat.plot(df.corr()['vhigh'],label='vhigh')
mat.plot(df.corr()['vhigh.1'],label='vhigh.1')
mat.plot(df.corr()['2'],label='2')
mat.legend()

mat.title('Correlation Heatmap')
mat.show()

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
y=df['unacc']

# %%
y
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1722    1
# 1723    3
# 1724    2
# 1725    1
# 1726    3
# Name: unacc, Length: 1727, dtype: int32

# %%
df['unacc'].value_counts()
# Out:
# unacc
# 2    1209
# 0     384
# 1      69
# 3      65
# Name: count, dtype: int64

# %%
df.drop(columns=['unacc'],inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2,stratify=y, random_state=0)

# %%
K = []
training = []
test = []
scores = {}

# %%
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, y_train)
    training_score = clf.score(X_train, y_train)
    training.append(training_score)
    test_score = clf.score(X_test, y_test)
    test.append(test_score)
    K.append(k)
    scores[k] = [training_score, test_score]

# %%
mat.plot(K,training,label="training")
mat.plot(K,test,label="test")
mat.legend()
mat.show()

# %%
clf = KNeighborsClassifier(n_neighbors = 7)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 0, 2, 0, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 0, 2, 0, 0, 2, 2, 2, 2, 0, 2, 3, 2, 2, 2, 2, 2,
#        0, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2,
#        3, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 2, 0, 2, 0,
#        0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 0, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 0, 0, 2, 0, 2, 2, 2, 0, 2, 2,
#        2, 2, 2, 0, 2, 2, 0, 2, 3, 0, 0, 2, 2, 2, 0, 2, 1, 2, 1, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 0, 2, 3, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2,
#        2, 0, 2, 2, 2, 0, 1, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 3, 2, 0, 2,
#        2, 2, 0, 2, 2, 1, 0, 0, 2, 0, 0, 2, 2, 0, 2, 0, 3, 2, 1, 2, 0, 2,
#        2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 0, 3, 0, 0, 2, 0, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 0, 2, 2, 2, 2, 2, 2, 3, 2,
#        2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2])

# %%
y_test
# Out:
# 738     2
# 989     2
# 1085    2
# 28      2
# 812     2
#        ..
# 172     2
# 676     2
# 102     2
# 1162    2
# 1675    2
# Name: unacc, Length: 346, dtype: int32

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_pred, y_test))
# Out:
# 0.8988439306358381

# %%
from sklearn.tree import *

# %%
K=[]
value={}

# %%
k=1
for i in range(2,20):
    for j in range(2,20):
        dt=DecisionTreeClassifier(criterion='entropy',max_depth=i,min_samples_split=j)
        dt.fit(X_train, y_train)
        ypred=dt.predict(X_test)
        K.append(accuracy_score(ypred,y_test))
        value[k]=[i,j]
        k=k+1

# %%
K.index(max(K))
# Out:
# 253

# %%
len(K)
# Out:
# 324

# %%
value[K.index(max(K))+1]
# Out:
# [16, 3]

# %%
grid_param={"criterion":["gini","entropy"],
             "max_depth":range(2,10,1),
             "min_samples_leaf":range(1,8,1),
             "min_samples_split":range(2,10,1) 
            }

# %%
clf = DecisionTreeClassifier(random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import *
grid_search=GridSearchCV(estimator=clf,param_grid=grid_param,cv=5,n_jobs=-1)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10)})

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 3}

# %%
dt=DecisionTreeClassifier(criterion='gini',max_depth=9,min_samples_leaf = 1,min_samples_split=3)
dt.fit(X_train, y_train)
ypred=dt.predict(X_test)

# %%
accuracy_score(ypred,y_test)
# Out:
# 0.9682080924855492

# %%
from sklearn import tree
mat.figure(figsize=(30,20))
tree.plot_tree(dt)
# Out:
# [Text(0.551025390625, 0.95, 'x[3] <= 0.5\ngini = 0.457\nsamples = 1381\nvalue = [307, 55, 967, 52]'),
#  Text(0.535400390625, 0.85, 'gini = 0.0\nsamples = 463\nvalue = [0, 0, 463, 0]'),
#  Text(0.566650390625, 0.85, 'x[5] <= 0.5\ngini = 0.58\nsamples = 918\nvalue = [307, 55, 504, 52]'),
#  Text(0.31689453125, 0.75, 'x[0] <= 2.5\ngini = 0.626\nsamples = 313\nvalue = [170, 24, 67, 52]'),
#  Text(0.1806640625, 0.65, 'x[0] <= 0.5\ngini = 0.606\nsamples = 231\nvalue = [131, 24, 24, 52]'),
#  Text(0.0625, 0.55, 'x[1] <= 2.5\ngini = 0.375\nsamples = 72\nvalue = [54, 0, 18, 0]'),
#  Text(0.046875, 0.45, 'x[2] <= 0.5\ngini = 0.069\nsamples = 56\nvalue = [54, 0, 2, 0]'),
#  Text(0.03125, 0.35, 'x[4] <= 1.5\ngini = 0.231\nsamples = 15\nvalue = [13, 0, 2, 0]'),
#  Text(0.015625, 0.25, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]'),
#  Text(0.046875, 0.25, 'x[3] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2, 0]'),
#  Text(0.03125, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.0625, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.0625, 0.35, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0, 0]'),
#  Text(0.078125, 0.45, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0]'),
#  Text(0.298828125, 0.55, 'x[1] <= 2.5\ngini = 0.634\nsamples = 159\nvalue = [77, 24, 6, 52]'),
#  Text(0.20703125, 0.45, 'x[4] <= 1.5\ngini = 0.665\nsamples = 119\nvalue = [38, 24, 5, 52]'),
#  Text(0.140625, 0.35, 'x[1] <= 0.5\ngini = 0.488\nsamples = 78\nvalue = [19, 7, 0, 52]'),
#  Text(0.109375, 0.25, 'x[0] <= 1.5\ngini = 0.49\nsamples = 28\nvalue = [16, 0, 0, 12]'),
#  Text(0.09375, 0.15, 'x[2] <= 1.5\ngini = 0.245\nsamples = 14\nvalue = [2, 0, 0, 12]'),
#  Text(0.078125, 0.05, 'gini = 0.444\nsamples = 6\nvalue = [2, 0, 0, 4]'),
#  Text(0.109375, 0.05, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]'),
#  Text(0.125, 0.15, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0, 0]'),
#  Text(0.171875, 0.25, 'x[2] <= 1.5\ngini = 0.337\nsamples = 50\nvalue = [3, 7, 0, 40]'),
#  Text(0.15625, 0.15, 'x[4] <= 0.5\ngini = 0.547\nsamples = 25\nvalue = [3, 7, 0, 15]'),
#  Text(0.140625, 0.05, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12]'),
#  Text(0.171875, 0.05, 'gini = 0.604\nsamples = 13\nvalue = [3, 7, 0, 3]'),
#  Text(0.1875, 0.15, 'gini = 0.0\nsamples = 25\nvalue = [0, 0, 0, 25]'),
#  Text(0.2734375, 0.35, 'x[1] <= 0.5\ngini = 0.598\nsamples = 41\nvalue = [19, 17, 5, 0]'),
#  Text(0.234375, 0.25, 'x[2] <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 0, 1, 0]'),
#  Text(0.21875, 0.15, 'x[3] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]'),
#  Text(0.203125, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.234375, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.25, 0.15, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]'),
#  Text(0.3125, 0.25, 'x[0] <= 1.5\ngini = 0.548\nsamples = 28\nvalue = [7, 17, 4, 0]'),
#  Text(0.28125, 0.15, 'x[2] <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [0, 11, 2, 0]'),
#  Text(0.265625, 0.05, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.296875, 0.05, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]'),
#  Text(0.34375, 0.15, 'x[1] <= 1.5\ngini = 0.604\nsamples = 15\nvalue = [7, 6, 2, 0]'),
#  Text(0.328125, 0.05, 'gini = 0.245\nsamples = 7\nvalue = [0, 6, 1, 0]'),
#  Text(0.359375, 0.05, 'gini = 0.219\nsamples = 8\nvalue = [7, 0, 1, 0]'),
#  Text(0.390625, 0.45, 'x[2] <= 0.5\ngini = 0.049\nsamples = 40\nvalue = [39, 0, 1, 0]'),
#  Text(0.375, 0.35, 'x[4] <= 1.5\ngini = 0.18\nsamples = 10\nvalue = [9, 0, 1, 0]'),
#  Text(0.359375, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]'),
#  Text(0.390625, 0.25, 'x[3] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]'),
#  Text(0.375, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.40625, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.40625, 0.35, 'gini = 0.0\nsamples = 30\nvalue = [30, 0, 0, 0]'),
#  Text(0.453125, 0.65, 'x[1] <= 2.5\ngini = 0.499\nsamples = 82\nvalue = [39, 0, 43, 0]'),
#  Text(0.4375, 0.55, 'x[1] <= 0.5\ngini = 0.455\nsamples = 60\nvalue = [39, 0, 21, 0]'),
#  Text(0.421875, 0.45, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0]'),
#  Text(0.453125, 0.45, 'x[2] <= 0.5\ngini = 0.093\nsamples = 41\nvalue = [39, 0, 2, 0]'),
#  Text(0.4375, 0.35, 'x[4] <= 1.5\ngini = 0.32\nsamples = 10\nvalue = [8, 0, 2, 0]'),
#  Text(0.421875, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.453125, 0.25, 'x[3] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2, 0]'),
#  Text(0.4375, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.46875, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.46875, 0.35, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0, 0]'),
#  Text(0.46875, 0.55, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22, 0]'),
#  Text(0.81640625, 0.75, 'x[5] <= 1.5\ngini = 0.424\nsamples = 605\nvalue = [137, 31, 437, 0]'),
#  Text(0.80078125, 0.65, 'gini = 0.0\nsamples = 300\nvalue = [0, 0, 300, 0]'),
#  Text(0.83203125, 0.65, 'x[4] <= 1.5\ngini = 0.586\nsamples = 305\nvalue = [137, 31, 137, 0]'),
#  Text(0.7421875, 0.55, 'x[0] <= 2.5\ngini = 0.581\nsamples = 206\nvalue = [115, 31, 60, 0]'),
#  Text(0.65625, 0.45, 'x[1] <= 2.5\ngini = 0.551\nsamples = 154\nvalue = [94, 31, 29, 0]'),
#  Text(0.59375, 0.35, 'x[0] <= 0.5\ngini = 0.506\nsamples = 115\nvalue = [74, 31, 10, 0]'),
#  Text(0.53125, 0.25, 'x[2] <= 0.5\ngini = 0.289\nsamples = 40\nvalue = [33, 0, 7, 0]'),
#  Text(0.5, 0.15, 'x[4] <= 0.5\ngini = 0.5\nsamples = 12\nvalue = [6, 0, 6, 0]'),
#  Text(0.484375, 0.05, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.515625, 0.05, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]'),
#  Text(0.5625, 0.15, 'x[2] <= 1.5\ngini = 0.069\nsamples = 28\nvalue = [27, 0, 1, 0]'),
#  Text(0.546875, 0.05, 'gini = 0.219\nsamples = 8\nvalue = [7, 0, 1, 0]'),
#  Text(0.578125, 0.05, 'gini = 0.0\nsamples = 20\nvalue = [20, 0, 0, 0]'),
#  Text(0.65625, 0.25, 'x[1] <= 0.5\ngini = 0.529\nsamples = 75\nvalue = [41, 31, 3, 0]'),
#  Text(0.625, 0.15, 'x[4] <= 0.5\ngini = 0.227\nsamples = 23\nvalue = [20, 0, 3, 0]'),
#  Text(0.609375, 0.05, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]'),
#  Text(0.640625, 0.05, 'gini = 0.42\nsamples = 10\nvalue = [7, 0, 3, 0]'),
#  Text(0.6875, 0.15, 'x[1] <= 1.5\ngini = 0.482\nsamples = 52\nvalue = [21, 31, 0, 0]'),
#  Text(0.671875, 0.05, 'gini = 0.328\nsamples = 29\nvalue = [6, 23, 0, 0]'),
#  Text(0.703125, 0.05, 'gini = 0.454\nsamples = 23\nvalue = [15, 8, 0, 0]'),
#  Text(0.71875, 0.35, 'x[0] <= 0.5\ngini = 0.5\nsamples = 39\nvalue = [20, 0, 19, 0]'),
#  Text(0.703125, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0]'),
#  Text(0.734375, 0.25, 'x[4] <= 0.5\ngini = 0.355\nsamples = 26\nvalue = [20, 0, 6, 0]'),
#  Text(0.71875, 0.15, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]'),
#  Text(0.75, 0.15, 'x[2] <= 1.5\ngini = 0.497\nsamples = 13\nvalue = [7, 0, 6, 0]'),
#  Text(0.734375, 0.05, 'gini = 0.245\nsamples = 7\nvalue = [1, 0, 6, 0]'),
#  Text(0.765625, 0.05, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.828125, 0.45, 'x[1] <= 0.5\ngini = 0.482\nsamples = 52\nvalue = [21, 0, 31, 0]'),
#  Text(0.8125, 0.35, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]'),
#  Text(0.84375, 0.35, 'x[1] <= 2.5\ngini = 0.494\nsamples = 38\nvalue = [21, 0, 17, 0]'),
#  Text(0.828125, 0.25, 'x[2] <= 1.5\ngini = 0.346\nsamples = 27\nvalue = [21, 0, 6, 0]'),
#  Text(0.8125, 0.15, 'x[4] <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [8, 0, 6, 0]'),
#  Text(0.796875, 0.05, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.828125, 0.05, 'gini = 0.375\nsamples = 8\nvalue = [2, 0, 6, 0]'),
#  Text(0.84375, 0.15, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]'),
#  Text(0.859375, 0.25, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]'),
#  Text(0.921875, 0.55, 'x[0] <= 0.5\ngini = 0.346\nsamples = 99\nvalue = [22, 0, 77, 0]'),
#  Text(0.90625, 0.45, 'gini = 0.0\nsamples = 27\nvalue = [0, 0, 27, 0]'),
#  Text(0.9375, 0.45, 'x[0] <= 1.5\ngini = 0.424\nsamples = 72\nvalue = [22, 0, 50, 0]'),
#  Text(0.90625, 0.35, 'x[1] <= 2.5\ngini = 0.461\nsamples = 25\nvalue = [16, 0, 9, 0]'),
#  Text(0.890625, 0.25, 'x[2] <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [16, 0, 2, 0]'),
#  Text(0.875, 0.15, 'x[3] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2, 0]'),
#  Text(0.859375, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.890625, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.90625, 0.15, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0, 0]'),
#  Text(0.921875, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]'),
#  Text(0.96875, 0.35, 'x[0] <= 2.5\ngini = 0.223\nsamples = 47\nvalue = [6, 0, 41, 0]'),
#  Text(0.953125, 0.25, 'x[1] <= 0.5\ngini = 0.408\nsamples = 21\nvalue = [6, 0, 15, 0]'),
#  Text(0.9375, 0.15, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0]'),
#  Text(0.96875, 0.15, 'x[1] <= 2.5\ngini = 0.497\nsamples = 13\nvalue = [6, 0, 7, 0]'),
#  Text(0.953125, 0.05, 'gini = 0.245\nsamples = 7\nvalue = [6, 0, 1, 0]'),
#  Text(0.984375, 0.05, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]'),
#  Text(0.984375, 0.25, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26, 0]')]
